# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import numpy as np

# %%
fig = plt.figure()
axs = plt.axes()

# %%
fig = plt.figure()
plt.plot(list(np.linspace(0,1,6))*5)

# %%
print(np.array([1,2])*3)
# Out:
# [3 6]

# %%
import math as m
x = np.arange(0,10,0.01)
fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(np.random.randn(50))

# %%
plt.plot(np.random.randn(50))
plt.xlim(25)
plt.ylim(-100,100)
# Out:
# (-100.0, 100.0)

# %%
ax1 = plt.axes()
ax2 = plt.axes([0.1,0.1,0.1,0.3])

# %%
import numpy as np
n = 30
np.random.seed(123)
df = pd.DataFrame({"date": np.random.choice(list("ABCDEF"), n),
                  "real_exe_time": np.random.randint(1, 100, n)})
df = df.sort_values(by="date").reindex()

#aggregate data for plotting
df_agg = df.groupby("date")["real_exe_time"].agg(mean="mean").reset_index()
df_agg["mean+30%"] = df_agg["mean"] * 1.3
df_agg["mean-30%"] = df_agg["mean"] * 0.7

#plot both into the same subplot
ax = df.plot.scatter(x='date', y='real_exe_time')
df_agg.plot(x='date', y=['mean', 'mean+30%', 'mean-30%'], ax=ax)

plt.show()

# %%
df
# Out:
#    date  real_exe_time
# 14    A             65
# 20    A             78
# 19    A             23
# 28    A             81
# 10    A             77
# 13    A             70
# 8     B             35
# 9     B             98
# 4     B             98
# 11    B             41
# 12    B              4
# 22    B             16
# 15    B             76
# 6     C             95
# 24    C             31
# 1     C              8
# 26    C             71
# 3     C             53
# 23    D             28
# 7     D             28
# 5     D             86
# 16    D             35
# 27    E             27
# 18    E             11
# 2     E             93
# 21    E             19
# 25    E             53
# 0     F             49
# 17    F             59
# 29    F              7

# %%
df.groupby("date")["real_exe_time"].agg(mean="mean").reset_index()
# Out:
#   date       mean
# 0    A  65.666667
# 1    B  52.571429
# 2    C  51.600000
# 3    D  44.250000
# 4    E  40.600000
# 5    F  38.333333

# %%
ax = df.plot.scatter(x='date', y='real_exe_time')
